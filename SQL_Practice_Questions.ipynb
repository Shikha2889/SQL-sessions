# %% [markdown]
# <a href="https://colab.research.google.com/github/Shikha2889/SQL-sessions/blob/main/SQL_Practice_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %% [markdown]
#  Q2. Rewrite the last query so that the rows that were not modified on December 29, 2000, are displayed.

# %% [markdown]
#  Q3. Rewrite the last query so that the rows that were not modified on December 29, 2000, are displayed.

# %% [markdown]
# Q4: Write a query using a WHERE clause that displays all the names in Person.Person with the middle name J. Display the first, last, and middle names along with the ID numbers.
